# %%
import pandas as pd

# %%
df = pd.read_csv("Jobs_IT.csv")
df.dropna
# Out:
# <bound method DataFrame.dropna of         job_id                            title  job_field  \
# 0     tcv_0001                Software Engineer  Developer
# 1     tcv_0002              Kinh doanh phần mềm      Sales
# 2     tcv_0003       Chuyên viên Cyber Security   Security
# 3     tcv_0004                    Data Engineer  Developer
# 4     tcv_0005                 Mobile Developer  Developer
# ...        ...                              ...        ...
# 4754  crv_0669                     data analyst      Other
# 4755  crv_0670          thực tập sinh fullstack  Fullstack
# 4756  crv_0671                          kế toán      Other
# 4757  crv_0672  cộng tác viên vận hành hệ thống      Other
# 4758  crv_0673             tư vấn marketing web      Other
#
#                                                 company    salary_max  \
# 0            TẬP ĐOÀN CÔNG NGHIỆP - VIỄN THÔNG QUÂN ĐỘI  4.000000e+07
# 1     CÔNG TY CỔ PHẦN DỊCH VỤ VÀ GIẢI PHÁP PHẦN MỀM ...  1.800000e+07
# ...
