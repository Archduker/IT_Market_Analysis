# %%
import pandas as pd

# %%
df = pd.read_csv("VNWS.csv")

# %%
dfb = df.head()
dfb
dfe =df.tail()
dfe
# Out:
#                                                  title  \
# 805                            Kĩ Sư QMS/ QMS Engineer
# 806                       Process Development Engineer
# 807  Chuyên Viên Phát Triển Cộng Đồng - Community S...
# 808  Senior Manager, Business Analysis - IT Departm...
# 809  Senior Officer, Business Intelligence (Life In...
#
#                                          company           location  \
# 805  CÔNG TY TNHH NANOFILM TECHNOLOGIES VIỆT NAM  Hà Nội, Hải Dương
# 806  CÔNG TY TNHH NANOFILM TECHNOLOGIES VIỆT NAM  Hải Dương, Hà Nội
# 807               CÔNG TY TNHH PATI GROUP AGENCY        Hồ Chí Minh
# 808                                  Techcombank             Hà Nội
# 809                                  Techcombank             Hà Nội
#
#                 salary    deadline  \
# 805       Thương lượng  2025-09-13
# 806       Thương lượng  2025-09-13
# 807  11tr-20tr ₫/tháng  2025-09-13
# 808       Thương lượng  2025-09-21
# 809       Thương lượng  2025-09-21
#
# ...

# %%
df = pd.concat([dfb,dfe], ignore_index=True)

# %%
df.to_csv("VNW.csv")
