# %%
import pandas as pd

# %%
df = pd.read_csv("CarrerViet.csv")

# %%
dfb = df.head()
dfb
dfe =df.tail()
dfe
# Out:
#                                    Tên tiêu đề  \
# 1002        Remote Software Engineering Intern
# 1003  Remote Data Automation Specialist Intern
# 1004                 [HCM] IT HELP DESK INTERN
# 1005           Cộng tác viên Vận hành hệ thống
# 1006            Nhân viên tư vấn Marketing Web
#
#                                     Tên Công ty  \
# 1002                           Springer Capital
# 1003                           Springer Capital
# 1004                         Classic Fine Foods
# 1005                                   GTEL ICT
# 1006  Công ty TNHH Thương mại Dịch vụ Web Ideas
#
#                                            link công ty Ngày cập nhật  \
# 1002  https://careerviet.vn/vi/nha-tuyen-dung/spring...    24/07/2025
# 1003  https://careerviet.vn/vi/nha-tuyen-dung/spring...    24/07/2025
# 1004  https://careerviet.vn/vi/nha-tuyen-dung/classi...    23/07/2025
# 1005  https://careerviet.vn/vi/nha-tuyen-dung/gtel-i...    23/07/2025
# ...

# %%
df = pd.concat([dfb,dfe], ignore_index=True)

# %%
df.to_csv("CV.csv")
