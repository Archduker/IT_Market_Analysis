# %%
import pandas as pd

# %%
df = pd.read_csv("TOPCV.csv")

# %%
dfb = df.head()
dfb
dfe =df.tail()
dfe
# Out:
#                                             Tên tiêu đề  \
# 2292                                    Unity Developer
# 2293                          EmbeddedSoftware Engineer
# 2294  Sales ExecutiveOMINI AI —Phát Triển Khách Hàng...
# 2295                                       Scrum Master
# 2296                               AutomationQA Manager
#
#                              Tên công ty              Lương  \
# 2292             Công ty TNHH Rainbow 5S  2,000 - 3,000 USD
# 2293        CÔNG TY CỔ PHẦN ĐIỆN TỬ SOJI         Thoả thuận
# 2294      Công ty cổ phần Công nghệ Sapo      10 - 30 triệu
# 2295  Công Ty Cổ Phần Aggregatori Capaci         Thoả thuận
# 2296             TECHVIFY SOFTWARE., JSC         Thoả thuận
#
#                 Thành Phố Kinh nghiệm Ngày hết hạn  \
# 2292          Hồ Chí Minh       4 năm   31/10/2025
# 2293               Hà Nội       3 năm   21/09/2025
# 2294  Hà Nội & 3 nơi khác  Dưới 1 năm   08/09/2025
# 2295               Hà Nội       3 năm   14/09/2025
# ...

# %%
df = pd.concat([dfb,dfe], ignore_index=True)

# %%
df.to_csv("TopCV.csv")
