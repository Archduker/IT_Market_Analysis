# %%
import pandas as pd

# %%
df = pd.read_csv("ITViet.csv")

# %%
dfb = df.head()
dfb
dfe =df.tail()
dfe
# Out:
#              job_id                                            job_url  \
# 975  Không xác định  https://itviec.com/it-jobs?page=49&job_selecte...
# 976  Không xác định  https://itviec.com/it-jobs?page=49&job_selecte...
# 977  Không xác định  https://itviec.com/it-jobs?page=49&job_selecte...
# 978  Không xác định  https://itviec.com/it-jobs?page=49&job_selecte...
# 979  Không xác định  https://itviec.com/it-jobs?page=49&job_selecte...
#
#                                                  title  \
# 975  Senior Frontend Engineer (React/NextJS)- $55K/...
# 976        .Net Backend Engineer (Intermediate/Senior)
# 977  Backend Developer (Python or PHP or NodeJS, En...
# 978  IT Operation & Maintenance (vận hành, bảo trì ...
# 979    Senior Fullstack Developer (NestJS, React, PHP)
#
#                                                company             salary  \
# 975                                           Crossian    Total $55k/year
# ...

# %%
df = pd.concat([dfb,dfe], ignore_index=True)

# %%
df.to_csv("ITV.csv")
