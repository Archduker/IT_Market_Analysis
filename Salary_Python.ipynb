# %%
import os
import re
import ast
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:,.0f}'.format

#  1) Load file 
df = pd.read_csv("Jobs_IT.csv", low_memory=False)
print("Số dòng:", len(df))

#  2) Xác định cột 
def find_col(df, possible_names):
    low_map = {c.lower(): c for c in df.columns}
    for name in possible_names:
        if name in df.columns: return name
        if name.lower() in low_map: return low_map[name.lower()]
    for c in df.columns:
        if any(name.lower() in c.lower() for name in possible_names):
            return c
    return None

col_min     = find_col(df, ["salary_min","min_salary","luong_min","lương_min"])
col_max     = find_col(df, ["salary_max","max_salary","luong_max","lương_max"])
col_industry= find_col(df, ["industry","ngành","nganh","category","chuyên môn","chuyen mon"])
col_city    = find_col(df, ["city","thành phố","thanh pho","location","tỉnh","tinh","province"])
col_level   = find_col(df, ["level","cấp bậc","seniority","position level"])
col_skills  = find_col(df, ["skills","kỹ năng","skill","ky nang"])
col_source  = find_col(df, ["source","nguồn","platform","jobsite","nguon"])

#  3) Chuẩn hoá lương 
df["_salary_min"] = pd.to_numeric(df[col_min], errors="coerce")
df["_salary_max"] = pd.to_numeric(df[col_max], errors="coerce")
df.loc[df["_salary_min"]<=0, "_salary_min"] = np.nan
df.loc[df["_salary_max"]<=0, "_salary_max"] = np.nan
df.loc[df["_salary_min"].notna() & df["_salary_max"].isna(), "_salary_max"] = df["_salary_min"]
df.loc[df["_salary_max"].notna() & df["_salary_min"].isna(), "_salary_min"] = df["_salary_max"]

# Đảm bảo min <= max
mask_swap = df["_salary_min"] > df["_salary_max"]
df.loc[mask_swap, ["_salary_min","_salary_max"]] = df.loc[mask_swap, ["_salary_max","_salary_min"]].values

df["_salary_mid"] = (df["_salary_min"] + df["_salary_max"]) / 2
df["_has_salary"] = df["_salary_min"].notna() & df["_salary_max"].notna()

#  4) Tổng quan 
overall = {
    "rows_total": len(df),
    "rows_with_salary": int(df["_has_salary"].sum()),
    "share_with_salary_%": round(100*df["_has_salary"].mean(), 2),
    "min_salary(VND)": df.loc[df["_has_salary"], "_salary_min"].min(),
    "avg_mid_salary(VND)": df.loc[df["_has_salary"], "_salary_mid"].mean(),
    "median_mid_salary(VND)": df.loc[df["_has_salary"], "_salary_mid"].median(),
    "max_salary(VND)": df.loc[df["_has_salary"], "_salary_max"].max(),
}
overall_df = pd.DataFrame([overall])
print("== Tổng quan lương ==")
display(overall_df)

# 5) Hàm thống kê theo nhóm  
df["__dummy__"] = 1

def group_stats(group_col, top_n=15):
    if group_col is None: 
        return pd.DataFrame()
    g = (df.groupby(group_col, dropna=False)
           .agg(
               postings=("__dummy__","sum"),
               disclosed=("_has_salary","sum"),
               disclosed_share=("_has_salary","mean"),
               mean_mid_vnd=("_salary_mid","mean"),
               median_mid_vnd=("_salary_mid","median"),
               min_min_vnd=("_salary_min","min"),
               max_max_vnd=("_salary_max","max")
           ).reset_index())
    g["disclosed_share"] = (g["disclosed_share"]*100).round(2)
    g = g.sort_values(["disclosed","mean_mid_vnd"], ascending=[False, False]).head(top_n)
    ordered = [group_col,"postings","disclosed","disclosed_share",
               "mean_mid_vnd","median_mid_vnd","min_min_vnd","max_max_vnd"]
    return g[ordered]

by_industry = group_stats(col_industry)
by_city     = group_stats(col_city)
by_level    = group_stats(col_level)
by_source   = group_stats(col_source)

print("\n== Top ngành công khai lương ==")
display(by_industry)
print("\n== Top thành phố ==")
display(by_city)
print("\n== Top cấp bậc ==")
display(by_level)
print("\n== Top nguồn đăng ==")
display(by_source)

#  6) Theo kỹ năng 
def explode_skills(df, col_skills):
    if col_skills is None: return pd.DataFrame()
    tmp = df[[col_skills,"_salary_mid","_has_salary","__dummy__"]].copy()
    tmp[col_skills] = (tmp[col_skills].astype(str)
                       .str.replace(r"[|;]|／|、", ",", regex=True))
    tmp = tmp.assign(skill=tmp[col_skills].str.split(",")).explode("skill")
    tmp["skill"] = tmp["skill"].astype(str).str.strip().str.lower()
    tmp = tmp[(tmp["skill"].notna()) & (tmp["skill"]!="") & (tmp["skill"]!="nan")]
    g = (tmp.groupby("skill", dropna=False)
           .agg(postings=("__dummy__","sum"),
                disclosed=("_has_salary","sum"),
                mean_mid_vnd=("_salary_mid","mean"))
           .reset_index()
           .sort_values(["disclosed","mean_mid_vnd"], ascending=[False, False])
           .head(30))
    return g

by_skill = explode_skills(df, col_skills)
print("\n== Top kỹ năng ==")
display(by_skill)

#  7) Biểu đồ 
plt.rcParams["figure.figsize"] = (10,5)

if not by_industry.empty:
    plt.barh(by_industry[col_industry].astype(str), by_industry["disclosed"])
    plt.title("Top ngành công khai lương nhiều nhất")
    plt.xlabel("Số tin có công khai lương")
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()

if not by_source.empty:
    plt.barh(by_source[col_source].astype(str), by_source["disclosed"])
    plt.title("Top nguồn công khai lương nhiều nhất")
    plt.xlabel("Số tin có công khai lương")
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()
# Out:
# Số dòng: 4754
# == Tổng quan lương ==
#    rows_total  rows_with_salary  share_with_salary_%  min_salary(VND)  \
# 0        4754              2304                   48                2
#
#    avg_mid_salary(VND)  median_mid_salary(VND)  max_salary(VND)
# 0          462,511,878              20,000,000  500,000,000,000
# == Top ngành công khai lương ==
#                                             industry  postings  disclosed  \
# 724                                               []      2383        939
# 425                                ['it - phần mềm']       328        173
# 526                                        ['other']       266        131
# 427                                  ['it/software']       278        122
# 628                         ['thiết kế / kiến trúc']        50         32
# 104                                   ['consulting']        78         31
# 206                                         ['game']        31         22
# 261  ['it - phần cứng và máy tính', 'it - phần mềm']        42         18
# 314  ['it - phần mềm', 'it - phần cứng và máy tính']        27         16
# 426                                   ['it support']        32         14
# 529                              ['sales/marketing']        19         13
# 55                                           ['b2b']        22         13
# 333      ['it - phần mềm', 'ngân hàng', 'tài chính']        13         12
# 465                        ['marketing / quảng cáo']        20         12
# 304                        ['it - phần mềm', 'game']        11         11
#
#      disclosed_share  mean_mid_vnd  median_mid_vnd  min_min_vnd  \
# 724               39    35,485,056      27,500,000            2
# 425               53    42,720,809      25,000,000      500,000
# 526               49 7,664,933,588      17,500,000    2,000,000
# 427               44    22,722,541      20,000,000    3,000,000
# 628               64    13,015,625      12,250,000    3,000,000
# 104               40    26,806,452      18,500,000    2,000,000
# 206               71    18,045,455      16,000,000    4,000,000
# 261               43    17,444,444      14,750,000    5,000,000
# 314               59    28,243,750      26,250,000    2,000,000
# 426               44    23,214,286      18,750,000   13,000,000
# 529               68    38,376,923      22,500,000    8,000,000
# 55                59    18,592,308      17,500,000    1,000,000
# 333               92    30,187,500      29,750,000   18,000,000
# 465               60    12,020,833      12,500,000    2,500,000
# 304              100    23,909,091      25,000,000    4,000,000
#
#         max_max_vnd
# 724   1,847,300,000
# 425   1,430,000,000
# 526 500,000,000,000
# 427     104,000,000
# 628      30,000,000
# 104     218,000,000
# 206      39,000,000
# 261      30,000,000
# 314      50,000,000
# 426      60,000,000
# 529     182,000,000
# 55       50,000,000
# 333      46,000,000
# 465      25,000,000
# 304      40,000,000
# == Top thành phố ==
#           location_city  postings  disclosed  disclosed_share  mean_mid_vnd  \
# 15               Hà Nội      2482       1354               55    29,919,199
# 31          Hồ Chí Minh       932        442               47 2,281,050,905
# 52      TP. Hồ Chí Minh       801        241               30    44,361,769
# 59          Unspecified        95         50               53    35,917,338
# 61              Đà Nẵng        94         35               37    24,966,843
# 3            Bình Dương        55         24               44    20,622,312
# 28            Hải Phòng        41         20               49    18,400,562
# 34  Hồ Chí Minh, Hà Nội        20         14               70    28,446,429
# 23  Hà Nội, Hồ Chí Minh        32         14               44    18,485,714
# 44              Nghệ An        16         13               81    11,057,692
# 64             Đồng Nai        18         11               61    17,880,227
# 7              Bắc Ninh        15          8               53    18,825,000
# 25             Hưng Yên        11          6               55    18,550,000
# 27            Hải Dương         6          6              100    13,666,667
# 37            Khánh Hoà         6          6              100    10,916,667
#
#     median_mid_vnd  min_min_vnd     max_max_vnd
# 15      21,500,000            2   1,847,300,000
# 31      15,000,000      500,000 500,000,000,000
# 52      39,585,000           60     263,900,000
# 59      27,535,250      422,240     131,950,000
# 61      14,000,000    3,000,000     145,145,000
# 3       15,000,000    3,000,000      79,170,000
# 28      15,000,000    8,000,000      50,000,000
# 34      26,250,000    2,000,000     100,000,000
# 23      16,750,000    3,000,000      57,200,000
# 44      10,000,000    7,000,000      25,000,000
# 64      15,500,000    8,000,000      52,780,000
# 7       14,000,000    7,000,000      72,800,000
# 25      20,900,000    5,000,000      25,000,000
# 27      11,500,000   10,000,000      30,000,000
# 37      12,250,000    7,000,000      15,000,000
# == Top cấp bậc ==
#        job_level  postings  disclosed  disclosed_share  mean_mid_vnd  \
# 3         Junior      1616       1000               62    23,410,265
# 2         Intern       567        375               66 2,677,568,800
# 7            Mid       655        254               39    31,536,330
# 11       Unknown       516        189               37    39,719,841
# 10        Senior       636        183               29    56,712,395
# 8         Middle       330        153               46    32,712,092
# 6        Manager       225         90               40    39,741,839
# 4           Lead       131         41               31    48,186,816
# 1       Director        20          8               40    93,015,938
# 9      Principal        28          6               21   108,911,800
# 5   Lead/Manager        21          3               14    59,000,000
# 0        C-Level         9          2               22    50,591,250
#
#     median_mid_vnd  min_min_vnd     max_max_vnd
# 3       17,500,000    2,000,000   1,430,000,000
# 2       10,000,000      500,000 500,000,000,000
# 7       29,166,667        1,500     156,000,000
# 11      36,946,000           20     197,925,000
# 10      40,000,000            2   1,847,300,000
# 8       22,500,000    8,000,000   1,430,000,000
# 6       37,000,000       52,780     158,340,000
# 4       42,500,000      923,650     175,933,333
# 1       85,767,500   13,195,000     263,900,000
# 9      119,458,733   20,000,000     186,929,167
# 5       50,000,000   35,000,000     104,000,000
# 0       50,591,250   39,585,000      70,000,000
# == Top nguồn đăng ==
#          source  postings  disclosed  disclosed_share  mean_mid_vnd  \
# 2         TopCV      2297       1393               61    21,908,507
# 1        ITviec       971        316               33    51,098,839
# 0      CareViet       673        311               46 3,242,872,508
# 3  VietnamWorks       813        284               35    36,719,134
#
#    median_mid_vnd  min_min_vnd     max_max_vnd
# 2      16,000,000      500,000   1,430,000,000
# 1      39,585,000            2   1,847,300,000
# 0      18,500,000    2,000,000 500,000,000,000
# 3      28,416,667        1,500     263,900,000
# == Top kỹ năng ==
#                      skill  postings  disclosed   mean_mid_vnd
# 6471                    []       690        380  1,340,057,895
# 6712           illustrator       210        162     12,085,494
# 2626           'giao tiếp'       161         94     18,648,936
# 5401                 ...)'       109         83     14,271,084
# 4987     'thiết kế đồ họa'       101         68     13,477,941
# 6410    ['thiết kế đồ họa'        90         66     13,034,091
# 6720            indesign)'        95         65     12,634,615
# 2645   'giải quyết vấn đề'       114         62     17,100,000
# 2043   'adobe illustrator'        95         60     11,045,833
# 6535                bố cục        64         56     10,863,393
# 6718              indesign        63         55     10,474,545
# 5138     'tư duy sáng tạo'        89         54     11,555,556
# 562             "english"]       132         52     44,990,317
# 4417       'quản lý dự án'       106         52     31,596,154
# 5989    ['adobe photoshop'        79         51     11,102,941
# 6086          ['giao tiếp'        80         49     22,891,837
# 6115               ['java'        92         48 10,447,333,333
# 2940          'javascript'        81         48 10,439,750,000
# 6211  ['kỹ năng giao tiếp'        69         46     15,413,043
# 4743            'sáng tạo'        61         45     11,138,889
# 1437               "react"       106         44     49,632,657
# 851           "javascript"       102         44     43,591,645
# 5371            'đàm phán'        67         44     19,125,000
# 6243      ['làm việc nhóm'        72         44     13,073,864
# 1633                 "sql"       124         43     39,135,251
# 2859                'html'        76         42 11,926,095,238
# 5144      'tư duy thẩm mỹ'        56         42     11,857,143
# 6827               màu sắc        52         42     10,508,333
# 1333              "python"       127         40     45,941,341
# 4575        'restful apis'        63         40     31,435,000
